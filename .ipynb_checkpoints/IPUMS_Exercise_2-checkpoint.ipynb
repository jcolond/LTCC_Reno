# %%
library(ipumsr)
library(dplyr)
library(tidyr)
library(ggplot2)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %% [markdown]
# **Part 1**

# %%
ddi <- read_ipums_ddi("usa_00074.xml")
data <- read_ipums_micro(ddi)
# Out:
# Use of data from IPUMS USA is subject to conditions including that users should cite the data appropriately. Use command `ipums_conditions()` for more details.

# %%
data %>% group_by(MORTGAGE = haven::as_factor(MORTGAGE)) %>% summarize(n=n()) %>%
# Out:
#   MORTGAGE                                      n       pct
# 1 N/A                                            888238 0.290113441
# 2 No, owned free and clear                       628501 0.205278976
# 3 Yes, mortgaged/ deed of trust or similar debt 1523041 0.497450756
# 4 Yes, contract to purchase                       21912 0.007156827

# %%
data %>% group_by(MORTGAGE=haven::as_factor(MORTGAGE)) %>% summarize(n=sum(PERWT)) %>% mutate(pct = n/sum(n))
# Out:
#   MORTGAGE                                      n         pct
# 1 N/A                                           107104033 0.346223180
# 2 No, owned free and clear                       53211365 0.172010404
# 3 Yes, mortgaged/ deed of trust or similar debt 146806345 0.474564385
# 4 Yes, contract to purchase                       2227946 0.007202031

# %%
data %>% filter(PERNUM == 1) %>% group_by(MORTGAGE = haven::as_factor(MORTGAGE)) %>% summarize(n= n()) %>% mutate(pct = n/sum(n))
# Out:
#   MORTGAGE                                      n      pct
# 1 N/A                                           426976 0.332619758
# 2 No, owned free and clear                      307864 0.239829988
# 3 Yes, mortgaged/ deed of trust or similar debt 541709 0.421998230
# 4 Yes, contract to purchase                       7127 0.005552024

# %%
data %>% filter(PERNUM == 1) %>% group_by(MORTAGE = haven::as_factor(MORTGAGE)) %>% summarize(n = sum(HHWT)) %>% mutate(PCT = n/sum(n))
# Out:
#   MORTAGE                                       n        PCT
# 1 N/A                                           47607067 0.388455433
# 2 No, owned free and clear                      24600389 0.200729752
# 3 Yes, mortgaged/ deed of trust or similar debt 49666435 0.405259087
# 4 Yes, contract to purchase                       680881 0.005555728

# %%
data %>% filter(VALUEH != 0 & VALUEH != 9999999 & PERNUM == 1) %>% group_by(MORTGAGE = haven::as_factor(MORTGAGE)) %>% summarize(VALUEH = weighted.mean(VALUEH, HHWT))
# Out:
#   MORTGAGE                                      VALUEH
# 1 No, owned free and clear                      219110.3
# 2 Yes, mortgaged/ deed of trust or similar debt 267941.3
# 3 Yes, contract to purchase                     144675.2

# %%
data_summary <- data %>% filter(VALUEH !=0 & VALUEH != 9999999 & PERNUM == 1)
ggplot(data_summary, aes(x = as.numeric(VALUEH), weight = HHWT)) + stat_bin(bins=30)
# Out:
# plot without title

# %% [markdown]
# **Part 2**

# %%
data %>% group_by(LANGUAGE = haven::as_factor(LANGUAGE, level = "both")) %>% summarize(n = sum(PERWT)) %>% mutate(pct = n/sum(n)) %>% arrange(desc(n))
# Out:
#    LANGUAGE                                    n         pct
# 1  [1] English                                 229753346 0.7426978406
# 56 [81] Siouan languages                        18464    5.968650e-05
# 57 [15] Celtic                                  18010    5.821890e-05
# 58 [83] Keres                                   13349    4.315181e-05
# 59 [64] African, n.s.                           13002    4.203011e-05
# 60 [78] Zuni                                     9936    3.211899e-05
# 61 [84] Iroquoian                                9030    2.919027e-05
# 62 [93] American Indian, n.s.                    6105    1.973495e-05

# %%
data %>% filter(LANGUAGE == 1) %>% summarize(mom_spanish = weighted.mean(LANGUAGE_MOM == 12, PERWT, na.rm = TRUE), mom_chinese = weighted.mean(LANGUAGE_MOM == 43, PERWT, na.rm = TRUE))
# Out:
#   mom_spanish mom_chinese
# 1 0.03890631  0.002225844

# %%
data %>% filter(haven::as_factor(SEX) == "Male" & AGE < 30) %>% group_by(LANGUAGE = haven::as_factor(LANGUAGE)) %>% summarize(n = sum(PERWT)) %>% mutate(pct = n/sum(n)) %>% arrange(desc(pct))
# Out:
#    LANGUAGE                               n        pct
# 1  English                                41701183 0.6490096083
# 2  N/A or blank                           10264433 0.1597488407
# 3  Spanish                                 8615686 0.1340888338
# 4  Chinese                                  459082 0.0071448484
# 5  Hindi and related                        381566 0.0059384406
# 6  French                                   329330 0.0051254741
# 7  Vietnamese                               250195 0.0038938694
# 8  German                                   194703 0.0030302286
# 9  Arabic                                   187287 0.0029148109
# 10 Filipino, Tagalog                        176588 0.0027482987
# 11 Korean                                   176132 0.0027412019
# 12 Russian                                  134207 0.0020887089
# 13 Dravidian                                112227 0.0017466267
# 14 Portuguese                               107884 0.0016790352
# 15 Sub-Saharan Africa                        92771 0.0014438264
# 16 Polish                                    78313 0.0012188117
# 17 Tibetan                                   74789 0.0011639665
# 18 Japanese                                  66519 0.0010352577
# 19 Persian, Iranian, Farsi                   58897 0.0009166339
# 20 Italian                                   56907 0.0008856629
# 21 Thai, Siamese, Lao                        50782 0.0007903374
# 22 Serbo-Croatian, Yugoslavian, Slavonian    48871 0.0007605959
# 23 Other East/Southeast Asian                43247 0.0006730677
# 24 Hebrew, Israeli                           41785 0.0006503141
# 25 Yiddish, Jewish                           41728 0.0006494270
# 26 Armenian                                  41230 0.0006416764
# 27 Micronesian, Polynesian                   35470 0.0005520316
# 28 Amharic, Ethiopian, etc.                  32558 0.0005067112
# 29 Hamitic                                   32341 0.0005033339
# 30 Indonesian                                31957 0.0004973576
# ⋮  ⋮                                      ⋮        ⋮
# 33 Navajo                                 30092    4.683320e-04
# 34 Dutch                                  26188    4.075727e-04
# 35 Ukrainian, Ruthenian, Little Russian   24193    3.765238e-04
# 36 Rumanian                               21458    3.339581e-04
# 37 Turkish                                20776    3.233439e-04
# 38 Native                                 16620    2.586627e-04
# 39 Near East Arabic dialect               15066    2.344773e-04
# 40 Other Balto-Slavic                     13276    2.066189e-04
# 41 Other Malayan                          11133    1.732666e-04
# 42 Other Persian dialects                 10846    1.688000e-04
# 43 Burmese, Lisu, Lolo                    10486    1.631972e-04
# 44 Magyar, Hungarian                       7287    1.134100e-04
# 45 Swedish                                 7042    1.095970e-04
# 46 Athapascan                              5697    8.866434e-05
# 47 Lithuanian                              5422    8.438442e-05
# 48 Aleut, Eskimo                           5112    7.955978e-05
# 49 Czech                                   5030    7.828359e-05
# 50 Norwegian                               4741    7.378579e-05
# 51 Siouan languages                        4551    7.082875e-05
# 52 Other or not reported                   4102    6.384081e-05
# 53 Hawaiian                                3712    5.777111e-05
# 54 Keres                                   3098    4.821522e-05
# 55 Finnish                                 2934    4.566283e-05
# 56 Slovak                                  2807    4.368629e-05
# 57 Danish                                  2788    4.339059e-05
# 58 Celtic                                  2061    3.207604e-05
# 59 African, n.s.                           2006    3.122006e-05
# 60 American Indian, n.s.                   1273    1.981213e-05
# 61 Zuni                                     840    1.307320e-05
# 62 Iroquoian                                760    1.182814e-05

# %% [markdown]
# **Part 3**

# %%
ddi <- read_ipums_ddi("usa_00075.xml")
data <- read_ipums_micro(ddi)
# Out:
# Use of data from IPUMS USA is subject to conditions including that users should cite the data appropriately. Use command `ipums_conditions()` for more details.

# %%
data %>% filter(PERNUM == 1 & METRO ==2) %>% group_by(YEAR) %>% summarize(own = weighted.mean(OWNERSHP == 1, HHWT))
# Out:
# Error in `filter()`:
# ℹ In argument: `PERNUM == 1 & METRO == 2`.
# Caused by error:
# ! object 'PERNUM' not found
# Traceback:
#
# 1. summarize(., own = weighted.mean(OWNERSHP == 1, HHWT))
# 2. group_by(., YEAR)
# 3. filter(., PERNUM == 1 & METRO == 2)
# 4. filter.data.frame(., PERNUM == 1 & METRO == 2)
# 5. filter_impl(.data = .data, ..., .by = {
#  .     {
#  .         .by
#  .     }
#  . }, .preserve = .preserve, .verb = "filter")
# 6. filter_rows(data = .data, dots = dots, by = by, verb = .verb,
#  .     error_call = .error_call, user_env = .user_env)
# 7. filter_eval(dots = dots, dots_expanded = dots_expanded, invert = invert,
#  .     mask = mask, error_call = error_call, user_env = user_env)
# 8. withCallingHandlers(mask$eval_all_filter(dots_expanded, invert,
#  .     env_filter), error = dplyr_error_handler(dots = dots, mask = mask,
#  .     bullets = filter_bullets, error_call = error_call), warning = function(cnd) {
#  .     local_error_context(dots, i, mask)
#  .     warning_handler(cnd)
#  . }, `dplyr:::signal_filter_one_column_matrix` = function(e) {
#  .     warn_filter_one_column_matrix(env = error_call, user_env = user_env)
#  . })
# 9. mask$eval_all_filter(dots_expanded, invert, env_filter)
# 10. eval()
# 11. .handleSimpleError(function (cnd)
#   . {
#   .     local_error_context(dots, i = frame[[i_sym]], mask = mask)
#   .     if (inherits(cnd, "dplyr:::internal_error")) {
#   .         parent <- error_cnd(message = bullets(cnd))
#   .     }
#   .     else {
#   .         parent <- cnd
#   .     }
#   .     message <- c(cnd_bullet_header(action), i = if (has_active_group_context(mask)) cnd_bullet_cur_group_label())
#   .     abort(message, class = error_class, parent = parent, call = error_call)
#   . }, "object 'PERNUM' not found", base::quote(NULL))
# 12. h(simpleError(msg, call))
# 13. abort(message, class = error_class, parent = parent, call = error_call)
# 14. signal_abort(cnd, .file)
# 15. signalCondition(cnd)
